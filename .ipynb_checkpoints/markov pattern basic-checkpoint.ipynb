# %%
from __future__ import division
from math import sqrt
import random as rnd

# %%
def checkGame(a, b):
    if a == '0' and b == '1' or a == '1' and b == '2' or a == '2' and b == '0':
        return -1
    elif a == b:
        return 0
    else:
        return 1

# %%
RPS_count = { '000' : 3, '001' : 3, '002' : 3, '010' : 3, '011' : 3, '012' : 3, '020' : 3, '021' : 3, '022' : 3, '100' : 3, '101' : 3, '102' : 3, '110' : 3, '111' : 3, '112' : 3, '120' : 3, '121' : 3, '122' : 3, '200' : 3, '201' : 3, '202' : 3, '210' : 3, '211' : 3, '212' : 3, '220' : 3, '221' : 3, '222' : 3 }

RPS_disp  = {'0' : 'rock', '1' : 'paper', '2' : 'scissor'}

# %%
wins, ties, losses = 0,0,0
last2 = '33'
#T-1, T

i=0

# %%
# Python3 program for Naive Pattern
# Searching algorithm
def search(pat, txt):
    M = len(pat)
    N = len(txt)
    


    # A loop to slide pat[] one by one */
    for i in range(N - M + 1):
        j = 0

        while(j < M):
            if (txt[i + j] != pat[j]):
                break
            j += 1

        if (j == M and i+3<N):
            print('pattern : --- '+ txt[i+3])
            flag=i
        
    return txt[flag+3]

# %%
history = ""

while(i<100):
    
    print(i)
    
    i = i+1
    
    roll = input('Please type r,p,s, or q\n')
    
    while(roll not in ['r', 'p', 's', 'q']):
        roll = input("Look: you've got to type r,p,s, or q\n")

    if roll == 'r':
        x = '0'
    elif roll == 'p':
        x = '1'
    elif roll == 's':
        x = '2'
    elif roll == 'q':
        quit()
      


    if(last2[0] == '3'):
        y = str( rnd.randint(0,2) )
    else:
        r_count = RPS_count[last2 + '0']
        p_count = RPS_count[last2 + '1']
        s_count = RPS_count[last2 + '2']
        
    


        tot_count = r_count + p_count + s_count


        q_dist = [ r_count/tot_count, p_count/tot_count, 1- (r_count/tot_count) - (p_count/tot_count) ]
        

        
        result = [ max(q_dist[2]-q_dist[1],0), max(q_dist[0]-q_dist[2],0), max(q_dist[1]-q_dist[0],0) ]
        resultnorm = sqrt(result[0]*result[0] + result[1]*result[1] + result[2]*result[2])
        result = [result[0]/resultnorm, result[1]/resultnorm, 1 - result[0]/resultnorm - result[1]/resultnorm]
        
        

        y = rnd.uniform(0,1)

        if y <= result[0]:
            y = '0'
        elif y <= result[0] + result[1]:
            y = '1'
        else:
            y = '2'

        #update dictionary
        RPS_count[last2+x] += 1
        
        
    print('y1 --- '+y) 

    last2 = last2[1] + x
    
    print('history -----  ' + history)
    if len(history)>5:
    
        last_chars = history[-3:]
        
        print('last_chars ---------------- '+ last_chars)
        temp = search(last_chars, history)
    
    
        if temp != None:
            print("hi")
            if temp=='0':
                y='1'
            elif temp=='1':
                y='2'
            else:
                y='0'
        

    print('y2 --- '+y) 
   

    print ('You played: ' + RPS_disp[x] + '\nI played:   ' + RPS_disp[y] + '\nGAME RESULT (-1 is a loss for you):', checkGame(x,y))

    if checkGame(x,y) == -1:
        losses += 1
    elif checkGame(x,y) == 0:
        ties   += 1
    elif checkGame(x,y) == 1:
        wins   += 1

    print ('Wins:', wins, 'Losses:', losses, 'Ties:', ties)
    history += x
# Out:
# 0
# Please type r,p,s, or q
# r
# y1 --- 0
# history -----
# y2 --- 0
# You played: rock
# I played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 0 Losses: 0 Ties: 1
# 1
# Please type r,p,s, or q
# p
# y1 --- 1
# history -----  0
# y2 --- 1
# You played: paper
# I played:   paper
# GAME RESULT (-1 is a loss for you): 0
# Wins: 0 Losses: 0 Ties: 2
# 2
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 0 Losses: 1 Ties: 2
# 3
# Please type r,p,s, or q
# r
# y1 --- 0
# history -----  012
# y2 --- 0
# You played: rock
# I played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 0 Losses: 1 Ties: 3
# 4
# Please type r,p,s, or q
# p
# y1 --- 0
# history -----  0120
# y2 --- 0
# You played: paper
# I played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 1 Losses: 1 Ties: 3
# 5
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01201
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 2 Ties: 3
# 6
# Please type r,p,s, or q
# r
# y1 --- 1
# history -----  012012
# last_chars ---------------- 012
# pattern : --- 0
# hi
# y2 --- 1
# You played: rock
# I played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 3 Ties: 3
# 7
# Please type r,p,s, or q
# p
# y1 --- 2
# history -----  0120120
# last_chars ---------------- 120
# pattern : --- 1
# hi
# y2 --- 2
# You played: paper
# I played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 4 Ties: 3
# 8
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01201201
# last_chars ---------------- 201
# pattern : --- 2
# hi
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 5 Ties: 3
# 9
# Please type r,p,s, or q
# r
# y1 --- 1
# history -----  012012012
# last_chars ---------------- 012
# pattern : --- 0
# pattern : --- 0
# hi
# y2 --- 1
# You played: rock
# I played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 6 Ties: 3
# 10
# Please type r,p,s, or q
# p
# y1 --- 2
# history -----  0120120120
# last_chars ---------------- 120
# pattern : --- 1
# pattern : --- 1
# hi
# y2 --- 2
# You played: paper
# I played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 7 Ties: 3
# 11
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01201201201
# last_chars ---------------- 201
# pattern : --- 2
# pattern : --- 2
# hi
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 8 Ties: 3
# 12
# Please type r,p,s, or q
# r
# y1 --- 1
# history -----  012012012012
# last_chars ---------------- 012
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# hi
# y2 --- 1
# You played: rock
# I played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 9 Ties: 3
# 13
# Please type r,p,s, or q
# p
# y1 --- 2
# history -----  0120120120120
# last_chars ---------------- 120
# pattern : --- 1
# pattern : --- 1
# pattern : --- 1
# hi
# y2 --- 2
# You played: paper
# I played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 10 Ties: 3
# 14
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01201201201201
# last_chars ---------------- 201
# pattern : --- 2
# pattern : --- 2
# pattern : --- 2
# hi
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 11 Ties: 3
# 15
# Please type r,p,s, or q
# r
# y1 --- 1
# history -----  012012012012012
# last_chars ---------------- 012
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# hi
# y2 --- 1
# You played: rock
# I played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 12 Ties: 3
# 16
# Please type r,p,s, or q
# p
# y1 --- 2
# history -----  0120120120120120
# last_chars ---------------- 120
# pattern : --- 1
# pattern : --- 1
# pattern : --- 1
# pattern : --- 1
# hi
# y2 --- 2
# You played: paper
# I played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 13 Ties: 3
# 17
# Please type r,p,s, or q
# s
# y1 --- 0
# history -----  01201201201201201
# last_chars ---------------- 201
# pattern : --- 2
# pattern : --- 2
# pattern : --- 2
# pattern : --- 2
# hi
# y2 --- 0
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 14 Ties: 3
# 18
# Please type r,p,s, or q
# s
# y1 --- 1
# history -----  012012012012012012
# last_chars ---------------- 012
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# pattern : --- 0
# hi
# y2 --- 1
# You played: scissor
# I played:   paper
# GAME RESULT (-1 is a loss for you): 1
# Wins: 2 Losses: 14 Ties: 3
# 19
# Please type r,p,s, or q
# p
# y1 --- 0
# history -----  0120120120120120122
# last_chars ---------------- 122
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-5c15f9957de8> in <module>
#      69
#      70         print('last_chars ---------------- '+ last_chars)
# ---> 71         temp = search(last_chars, history)
#      72
#      73
#
# <ipython-input-11-ae94867ca987> in search(pat, txt)
#      20             flag=i
#      21
# ---> 22     return txt[flag+3]
#      23
#
# UnboundLocalError: local variable 'flag' referenced before assignment
