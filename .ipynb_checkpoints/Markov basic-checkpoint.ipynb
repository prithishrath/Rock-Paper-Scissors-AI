# %%
from __future__ import division
from math import sqrt
import random as rnd

def checkGame(a, b):
    if a == '0' and b == '1' or a == '1' and b == '2' or a == '2' and b == '0':
        return -1
    elif a == b:
        return 0
    else:
        return 1

RPS_count = { '000' : 3, '001' : 3, '002' : 3, '010' : 3, '011' : 3, '012' : 3, '020' : 3, '021' : 3, '022' : 3, '100' : 3, '101' : 3, '102' : 3, '110' : 3, '111' : 3, '112' : 3, '120' : 3, '121' : 3, '122' : 3, '200' : 3, '201' : 3, '202' : 3, '210' : 3, '211' : 3, '212' : 3, '220' : 3, '221' : 3, '222' : 3 }

RPS_disp  = {'0' : 'rock', '1' : 'paper', '2' : 'scissor'}


wins, ties, losses = 0,0,0
last2 = '33'
#T-1, T

#Loops until user presses q
while(1):
    roll = input('Please type r,p,s, or q\n')
    
    while(roll not in ['r', 'p', 's', 'q']):
        roll = input("Look: you've got to type r,p,s, or q\n")

    if roll == 'r':
        x = '0'
    elif roll == 'p':
        x = '1'
    elif roll == 's':
        x = '2'
    elif roll == 'q':
        quit()
        

    if(last2[0] == '3'):
        y = str( rnd.randint(0,2) )
    else:
        r_count = RPS_count[last2 + '0']
        p_count = RPS_count[last2 + '1']
        s_count = RPS_count[last2 + '2']
        
        
        print('r_count ', r_count) 
        print('p_count ', p_count) 
        print('s_count ', s_count) 


        tot_count = r_count + p_count + s_count
        print('tot_count ',tot_count)

        q_dist = [ r_count/tot_count, p_count/tot_count, 1- (r_count/tot_count) - (p_count/tot_count) ]
        
        print('q_dist ', q_dist)
        
        result = [ max(q_dist[2]-q_dist[1],0), max(q_dist[0]-q_dist[2],0), max(q_dist[1]-q_dist[0],0) ]
        resultnorm = sqrt(result[0]*result[0] + result[1]*result[1] + result[2]*result[2])
        result = [result[0]/resultnorm, result[1]/resultnorm, 1 - result[0]/resultnorm - result[1]/resultnorm]
        
        
        print('resultnorm ',resultnorm)
                
        print('result ',result)

        y = rnd.uniform(0,1)

        if y <= result[0]:
            y = '0'
        elif y <= result[0] + result[1]:
            y = '1'
        else:
            y = '2'

        #update dictionary
        RPS_count[last2+x] += 1
        
        print ('RPS_count ', RPS_count)

    last2 = last2[1] + x
    
   

    print ('You played: ' + RPS_disp[x] + '\nI played:   ' + RPS_disp[y] + '\nGAME RESULT (-1 is a loss for you):', checkGame(x,y))

    if checkGame(x,y) == -1:
        losses += 1
    elif checkGame(x,y) == 0:
        ties   += 1
    elif checkGame(x,y) == 1:
        wins   += 1

    print ('Wins:', wins, 'Losses:', losses, 'Ties:', ties)
# Out:
# Please type r,p,s, or q
# r
# You played: rock
# I played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 0 Losses: 1 Ties: 0
# Please type r,p,s, or q
# p
# You played: paper
# I played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 0 Losses: 2 Ties: 0
# Please type r,p,s, or q
# s
# r_count  3
# p_count  3
# s_count  3
# tot_count  9
# q_dist  [0.3333333333333333, 0.3333333333333333, 0.3333333333333334]
# resultnorm  1.1102230246251565e-16
# result  [1.0, 0.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 4, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 3, '121': 3, '122': 3, '200': 3, '201': 3, '202': 3, '210': 3, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 0 Losses: 3 Ties: 0
# Please type r,p,s, or q
# r
# r_count  3
# p_count  3
# s_count  3
# tot_count  9
# q_dist  [0.3333333333333333, 0.3333333333333333, 0.3333333333333334]
# resultnorm  1.1102230246251565e-16
# result  [1.0, 0.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 4, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 4, '121': 3, '122': 3, '200': 3, '201': 3, '202': 3, '210': 3, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: rock
# I played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 0 Losses: 3 Ties: 1
# Please type r,p,s, or q
# p
# r_count  3
# p_count  3
# s_count  3
# tot_count  9
# q_dist  [0.3333333333333333, 0.3333333333333333, 0.3333333333333334]
# resultnorm  1.1102230246251565e-16
# result  [1.0, 0.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 4, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 4, '121': 3, '122': 3, '200': 3, '201': 4, '202': 3, '210': 3, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: paper
# I played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 1 Losses: 3 Ties: 1
# Please type r,p,s, or q
# s
# r_count  3
# p_count  3
# s_count  4
# tot_count  10
# q_dist  [0.3, 0.3, 0.39999999999999997]
# resultnorm  0.09999999999999998
# result  [1.0, 0.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 5, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 4, '121': 3, '122': 3, '200': 3, '201': 4, '202': 3, '210': 3, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: scissor
# I played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 1 Losses: 4 Ties: 1
# Please type r,p,s, or q
# p
# r_count  4
# p_count  3
# s_count  3
# tot_count  10
# q_dist  [0.4, 0.3, 0.3]
# resultnorm  0.10000000000000003
# result  [0.0, 1.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 5, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 4, '121': 4, '122': 3, '200': 3, '201': 4, '202': 3, '210': 3, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: paper
# I played:   paper
# GAME RESULT (-1 is a loss for you): 0
# Wins: 1 Losses: 4 Ties: 2
# Please type r,p,s, or q
# r
# r_count  3
# p_count  3
# s_count  3
# tot_count  9
# q_dist  [0.3333333333333333, 0.3333333333333333, 0.3333333333333334]
# resultnorm  1.1102230246251565e-16
# result  [1.0, 0.0, 0.0]
# RPS_count  {'000': 3, '001': 3, '002': 3, '010': 3, '011': 3, '012': 5, '020': 3, '021': 3, '022': 3, '100': 3, '101': 3, '102': 3, '110': 3, '111': 3, '112': 3, '120': 4, '121': 4, '122': 3, '200': 3, '201': 4, '202': 3, '210': 4, '211': 3, '212': 3, '220': 3, '221': 3, '222': 3}
# You played: rock
# I played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 1 Losses: 4 Ties: 3
