# %%
from __future__ import division
from math import sqrt
import random as rnd
from random import choice

def checkGame(a, b):
    if a == '0' and b == '1' or a == '1' and b == '2' or a == '2' and b == '0':
        return -1
    elif a == b:
        return 0
    else:
        return 1

RPS_disp  = {'0' : 'rock', '1' : 'paper', '2' : 'scissor'}


wins, ties, losses = 0,0,0




i=0
while(i<100):
    print(i)
    roll = input('Please type r,p,s, or q\n')
    
    while(roll not in ['r', 'p', 's', 'q']):
        roll = input("Look: you've got to type r,p,s, or q\n")

    if roll == 'r':
        x = '0'
    elif roll == 'p':
        x = '1'
    elif roll == 's':
        x = '2'
    i = i+1
    
    if roll == 'r':
        x = '0'
    elif roll == 'p':
        x = '1'
    elif roll == 's':
        x = '2'
        
        

    y = str( rnd.randint(0,2) )
   
   

    print ('User played: ' + RPS_disp[x] + '\nComputer played:   ' + RPS_disp[y] + '\nGAME RESULT (-1 is a loss for you):', checkGame(x,y))

    if checkGame(x,y) == -1:
        losses += 1
    elif checkGame(x,y) == 0:
        ties   += 1
    elif checkGame(x,y) == 1:
        wins   += 1

    print ('Wins:', wins, 'Losses:', losses, 'Ties:', ties)
# Out:
# 0
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 1 Losses: 0 Ties: 0
# 1
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 0
# Wins: 1 Losses: 0 Ties: 1
# 2
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 1
# Wins: 2 Losses: 0 Ties: 1
# 3
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 2 Losses: 1 Ties: 1
# 4
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 3 Losses: 1 Ties: 1
# 5
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 3 Losses: 2 Ties: 1
# 6
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 3 Losses: 2 Ties: 2
# 7
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 3 Losses: 3 Ties: 2
# 8
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 3 Losses: 3 Ties: 3
# 9
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 3 Losses: 3 Ties: 4
# 10
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 4 Losses: 3 Ties: 4
# 11
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 1
# Wins: 5 Losses: 3 Ties: 4
# 12
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 6 Losses: 3 Ties: 4
# 13
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 0
# Wins: 6 Losses: 3 Ties: 5
# 14
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 6 Losses: 3 Ties: 6
# 15
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 6 Losses: 3 Ties: 7
# 16
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 7 Losses: 3 Ties: 7
# 17
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 1
# Wins: 8 Losses: 3 Ties: 7
# 18
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 8 Losses: 4 Ties: 7
# 19
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 8 Losses: 5 Ties: 7
# 20
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 8 Losses: 5 Ties: 8
# 21
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 8 Losses: 6 Ties: 8
# 22
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): -1
# Wins: 8 Losses: 7 Ties: 8
# 23
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 8 Losses: 7 Ties: 9
# 24
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 9 Losses: 7 Ties: 9
# 25
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 10 Losses: 7 Ties: 9
# 26
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 10 Losses: 8 Ties: 9
# 27
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 1
# Wins: 11 Losses: 8 Ties: 9
# 28
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 11 Losses: 8 Ties: 10
# 29
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 1
# Wins: 12 Losses: 8 Ties: 10
# 30
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   paper
# GAME RESULT (-1 is a loss for you): 0
# Wins: 12 Losses: 8 Ties: 11
# 31
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 13 Losses: 8 Ties: 11
# 32
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 13 Losses: 8 Ties: 12
# 33
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 13 Losses: 8 Ties: 13
# 34
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 13 Losses: 9 Ties: 13
# 35
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): -1
# Wins: 13 Losses: 10 Ties: 13
# 36
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 14 Losses: 10 Ties: 13
# 37
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   scissor
# GAME RESULT (-1 is a loss for you): 0
# Wins: 14 Losses: 10 Ties: 14
# 38
# Please type r,p,s, or q
# r
# User played: rock
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 0
# Wins: 14 Losses: 10 Ties: 15
# 39
# Please type r,p,s, or q
# s
# User played: scissor
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): -1
# Wins: 14 Losses: 11 Ties: 15
# 40
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you): 1
# Wins: 15 Losses: 11 Ties: 15
# 41
# Please type r,p,s, or q
# p
# User played: paper
# Computer played:   rock
# GAME RESULT (-1 is a loss for you):